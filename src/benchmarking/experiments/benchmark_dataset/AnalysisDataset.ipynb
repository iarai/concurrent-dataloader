# %%
from benchmarking.analysis.analyze_results import *

# %%
output_base_folder = Path("/iarai/home/ivan.svogor/storage-benchmarking/benchmark_output/1512-benchmark_dataset")

# %%
group_by_dataset=["dataset", "pool_size"]

# %%
df_dataset = extract_pandas(output_base_folder, folder_filter="*dataset*")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1397/1397 [00:03<00:00, 417.63it/s]

# %%
print(df_dataset.groupby(group_by_dataset).groups.keys())
# Out:
# dict_keys([('s3', 1), ('s3', 2), ('s3', 3), ('s3', 4), ('s3', 5), ('s3', 6), ('s3', 7), ('s3', 10), ('s3', 15), ('s3', 20), ('s3', 30), ('s3', 40), ('s3', 50), ('s3', 60), ('s3', 80), ('scratch', 1), ('scratch', 2), ('scratch', 3), ('scratch', 4), ('scratch', 5), ('scratch', 6), ('scratch', 7), ('scratch', 10), ('scratch', 15), ('scratch', 20), ('scratch', 30), ('scratch', 40), ('scratch', 50), ('scratch', 60), ('scratch', 80)])

# %%
display(get_run_stats(df_dataset, group_by=group_by_dataset))
# Out:
#                                                              downloaded data [B]  \
# dataset pool_size run
# s3      1         20211215f153749_benchmark_dataset_s3                 224930874
#         2         20211215f154403_benchmark_dataset_s3                 236899544
#         3         20211215f154716_benchmark_dataset_s3                 229160984
#         4         20211215f154928_benchmark_dataset_s3                 222474138
#         5         20211215f155109_benchmark_dataset_s3                 243713302
#         6         20211215f155235_benchmark_dataset_s3                 234899188
#         7         20211215f155351_benchmark_dataset_s3                 234670466
#         10        20211215f155500_benchmark_dataset_s3                 235347322
#         15        20211215f155600_benchmark_dataset_s3                 226691170
#         20        20211215f155702_benchmark_dataset_s3                 224494018
#         30        20211215f155808_benchmark_dataset_s3                 231463319
#         40        20211215f155926_benchmark_dataset_s3                 221235825
#         50        20211215f160057_benchmark_dataset_s3                 225574274
#         60        20211215f160239_benchmark_dataset_s3                 223628186
#         80        20211215f160427_benchmark_dataset_s3                 227902602
# scratch 1         20211215f160641_benchmark_dataset_scratch            236519922
#         2         20211215f160656_benchmark_dataset_scratch            236355252
#         3         20211215f160708_benchmark_dataset_scratch            239649060
#         4         20211215f160733_benchmark_dataset_scratch            250685784
#         5         20211215f160808_benchmark_dataset_scratch            228977770
#         6         20211215f160848_benchmark_dataset_scratch            234465648
#         7         20211215f160929_benchmark_dataset_scratch            234295579
#         10        20211215f161014_benchmark_dataset_scratch            242147310
#         15        20211215f161101_benchmark_dataset_scratch            242553525
#         20        20211215f161149_benchmark_dataset_scratch            211359220
#         30        20211215f161223_benchmark_dataset_scratch            210899490
#         40        20211215f161332_benchmark_dataset_scratch            210141360
#         50        20211215f161455_benchmark_dataset_scratch            222797500
#         60        20211215f161631_benchmark_dataset_scratch            246559740
#         80        20211215f161800_benchmark_dataset_scratch            283890960
#
#                                                                time_start  \
# dataset pool_size run
# s3      1         20211215f153749_benchmark_dataset_s3       1.639579e+09
#         2         20211215f154403_benchmark_dataset_s3       1.639579e+09
#         3         20211215f154716_benchmark_dataset_s3       1.639580e+09
#         4         20211215f154928_benchmark_dataset_s3       1.639580e+09
#         5         20211215f155109_benchmark_dataset_s3       1.639580e+09
#         6         20211215f155235_benchmark_dataset_s3       1.639580e+09
#         7         20211215f155351_benchmark_dataset_s3       1.639580e+09
#         10        20211215f155500_benchmark_dataset_s3       1.639580e+09
#         15        20211215f155600_benchmark_dataset_s3       1.639580e+09
#         20        20211215f155702_benchmark_dataset_s3       1.639580e+09
#         30        20211215f155808_benchmark_dataset_s3       1.639580e+09
#         40        20211215f155926_benchmark_dataset_s3       1.639580e+09
#         50        20211215f160057_benchmark_dataset_s3       1.639580e+09
#         60        20211215f160239_benchmark_dataset_s3       1.639581e+09
#         80        20211215f160427_benchmark_dataset_s3       1.639581e+09
# scratch 1         20211215f160641_benchmark_dataset_scratch  1.639581e+09
#         2         20211215f160656_benchmark_dataset_scratch  1.639581e+09
#         3         20211215f160708_benchmark_dataset_scratch  1.639581e+09
#         4         20211215f160733_benchmark_dataset_scratch  1.639581e+09
#         5         20211215f160808_benchmark_dataset_scratch  1.639581e+09
#         6         20211215f160848_benchmark_dataset_scratch  1.639581e+09
#         7         20211215f160929_benchmark_dataset_scratch  1.639581e+09
#         10        20211215f161014_benchmark_dataset_scratch  1.639581e+09
#         15        20211215f161101_benchmark_dataset_scratch  1.639581e+09
#         20        20211215f161149_benchmark_dataset_scratch  1.639581e+09
#         30        20211215f161223_benchmark_dataset_scratch  1.639581e+09
#         40        20211215f161332_benchmark_dataset_scratch  1.639581e+09
#         50        20211215f161455_benchmark_dataset_scratch  1.639581e+09
#         60        20211215f161631_benchmark_dataset_scratch  1.639581e+09
#         80        20211215f161800_benchmark_dataset_scratch  1.639582e+09
#
#                                                                  time_end  \
# dataset pool_size run
# s3      1         20211215f153749_benchmark_dataset_s3       1.639579e+09
#         2         20211215f154403_benchmark_dataset_s3       1.639580e+09
#         3         20211215f154716_benchmark_dataset_s3       1.639580e+09
#         4         20211215f154928_benchmark_dataset_s3       1.639580e+09
#         5         20211215f155109_benchmark_dataset_s3       1.639580e+09
#         6         20211215f155235_benchmark_dataset_s3       1.639580e+09
#         7         20211215f155351_benchmark_dataset_s3       1.639580e+09
#         10        20211215f155500_benchmark_dataset_s3       1.639580e+09
#         15        20211215f155600_benchmark_dataset_s3       1.639580e+09
#         20        20211215f155702_benchmark_dataset_s3       1.639580e+09
#         30        20211215f155808_benchmark_dataset_s3       1.639580e+09
#         40        20211215f155926_benchmark_dataset_s3       1.639580e+09
#         50        20211215f160057_benchmark_dataset_s3       1.639581e+09
#         60        20211215f160239_benchmark_dataset_s3       1.639581e+09
#         80        20211215f160427_benchmark_dataset_s3       1.639581e+09
# scratch 1         20211215f160641_benchmark_dataset_scratch  1.639581e+09
#         2         20211215f160656_benchmark_dataset_scratch  1.639581e+09
#         3         20211215f160708_benchmark_dataset_scratch  1.639581e+09
#         4         20211215f160733_benchmark_dataset_scratch  1.639581e+09
#         5         20211215f160808_benchmark_dataset_scratch  1.639581e+09
#         6         20211215f160848_benchmark_dataset_scratch  1.639581e+09
#         7         20211215f160929_benchmark_dataset_scratch  1.639581e+09
#         10        20211215f161014_benchmark_dataset_scratch  1.639581e+09
#         15        20211215f161101_benchmark_dataset_scratch  1.639581e+09
#         20        20211215f161149_benchmark_dataset_scratch  1.639581e+09
#         30        20211215f161223_benchmark_dataset_scratch  1.639581e+09
#         40        20211215f161332_benchmark_dataset_scratch  1.639581e+09
#         50        20211215f161455_benchmark_dataset_scratch  1.639581e+09
#         60        20211215f161631_benchmark_dataset_scratch  1.639581e+09
#         80        20211215f161800_benchmark_dataset_scratch  1.639582e+09
#
#                                                              total_elpased_time [s]  \
# dataset pool_size run
# s3      1         20211215f153749_benchmark_dataset_s3                   367.266549
#         2         20211215f154403_benchmark_dataset_s3                   187.185671
#         3         20211215f154716_benchmark_dataset_s3                   124.008109
#         4         20211215f154928_benchmark_dataset_s3                    91.922485
#         5         20211215f155109_benchmark_dataset_s3                    75.408057
#         6         20211215f155235_benchmark_dataset_s3                    64.413101
#         7         20211215f155351_benchmark_dataset_s3                    55.726548
#         10        20211215f155500_benchmark_dataset_s3                    44.258270
#         15        20211215f155600_benchmark_dataset_s3                    40.738059
#         20        20211215f155702_benchmark_dataset_s3                    40.050954
#         30        20211215f155808_benchmark_dataset_s3                    41.357387
#         40        20211215f155926_benchmark_dataset_s3                    41.777747
#         50        20211215f160057_benchmark_dataset_s3                    41.668163
#         60        20211215f160239_benchmark_dataset_s3                    44.941120
#         80        20211215f160427_benchmark_dataset_s3                    46.651663
# scratch 1         20211215f160641_benchmark_dataset_scratch                9.530603
#         2         20211215f160656_benchmark_dataset_scratch                5.454959
#         3         20211215f160708_benchmark_dataset_scratch               18.082155
#         4         20211215f160733_benchmark_dataset_scratch               25.195438
#         5         20211215f160808_benchmark_dataset_scratch               29.974142
#         6         20211215f160848_benchmark_dataset_scratch               29.854063
#         7         20211215f160929_benchmark_dataset_scratch               31.875823
#         10        20211215f161014_benchmark_dataset_scratch               31.476393
#         15        20211215f161101_benchmark_dataset_scratch               27.283637
#         20        20211215f161149_benchmark_dataset_scratch                7.484763
#         30        20211215f161223_benchmark_dataset_scratch               33.460271
#         40        20211215f161332_benchmark_dataset_scratch               36.002781
#         50        20211215f161455_benchmark_dataset_scratch               36.215431
#         60        20211215f161631_benchmark_dataset_scratch               21.964478
#         80        20211215f161800_benchmark_dataset_scratch               30.369888
#
#                                                              downloaded data [MB]  \
# dataset pool_size run
# s3      1         20211215f153749_benchmark_dataset_s3                 224.930874
#         2         20211215f154403_benchmark_dataset_s3                 236.899544
#         3         20211215f154716_benchmark_dataset_s3                 229.160984
#         4         20211215f154928_benchmark_dataset_s3                 222.474138
#         5         20211215f155109_benchmark_dataset_s3                 243.713302
#         6         20211215f155235_benchmark_dataset_s3                 234.899188
#         7         20211215f155351_benchmark_dataset_s3                 234.670466
#         10        20211215f155500_benchmark_dataset_s3                 235.347322
#         15        20211215f155600_benchmark_dataset_s3                 226.691170
#         20        20211215f155702_benchmark_dataset_s3                 224.494018
#         30        20211215f155808_benchmark_dataset_s3                 231.463319
#         40        20211215f155926_benchmark_dataset_s3                 221.235825
#         50        20211215f160057_benchmark_dataset_s3                 225.574274
#         60        20211215f160239_benchmark_dataset_s3                 223.628186
#         80        20211215f160427_benchmark_dataset_s3                 227.902602
# scratch 1         20211215f160641_benchmark_dataset_scratch            236.519922
#         2         20211215f160656_benchmark_dataset_scratch            236.355252
#         3         20211215f160708_benchmark_dataset_scratch            239.649060
#         4         20211215f160733_benchmark_dataset_scratch            250.685784
#         5         20211215f160808_benchmark_dataset_scratch            228.977770
#         6         20211215f160848_benchmark_dataset_scratch            234.465648
#         7         20211215f160929_benchmark_dataset_scratch            234.295579
#         10        20211215f161014_benchmark_dataset_scratch            242.147310
#         15        20211215f161101_benchmark_dataset_scratch            242.553525
#         20        20211215f161149_benchmark_dataset_scratch            211.359220
#         30        20211215f161223_benchmark_dataset_scratch            210.899490
#         40        20211215f161332_benchmark_dataset_scratch            210.141360
#         50        20211215f161455_benchmark_dataset_scratch            222.797500
#         60        20211215f161631_benchmark_dataset_scratch            246.559740
#         80        20211215f161800_benchmark_dataset_scratch            283.890960
#
#                                                              throughput [MBit/s]
# dataset pool_size run
# s3      1         20211215f153749_benchmark_dataset_s3                  4.899567
#         2         20211215f154403_benchmark_dataset_s3                 10.124687
#         3         20211215f154716_benchmark_dataset_s3                 14.783613
#         4         20211215f154928_benchmark_dataset_s3                 19.361891
#         5         20211215f155109_benchmark_dataset_s3                 25.855412
#         6         20211215f155235_benchmark_dataset_s3                 29.174088
#         7         20211215f155351_benchmark_dataset_s3                 33.688857
#         10        20211215f155500_benchmark_dataset_s3                 42.540718
#         15        20211215f155600_benchmark_dataset_s3                 44.516833
#         20        20211215f155702_benchmark_dataset_s3                 44.841682
#         30        20211215f155808_benchmark_dataset_s3                 44.773296
#         40        20211215f155926_benchmark_dataset_s3                 42.364338
#         50        20211215f160057_benchmark_dataset_s3                 43.308706
#         60        20211215f160239_benchmark_dataset_s3                 39.808208
#         80        20211215f160427_benchmark_dataset_s3                 39.081583
# scratch 1         20211215f160641_benchmark_dataset_scratch           198.535108
#         2         20211215f160656_benchmark_dataset_scratch           346.628064
#         3         20211215f160708_benchmark_dataset_scratch           106.026771
#         4         20211215f160733_benchmark_dataset_scratch            79.597198
#         5         20211215f160808_benchmark_dataset_scratch            61.113414
#         6         20211215f160848_benchmark_dataset_scratch            62.829814
#         7         20211215f160929_benchmark_dataset_scratch            58.802078
#         10        20211215f161014_benchmark_dataset_scratch            61.543852
#         15        20211215f161101_benchmark_dataset_scratch            71.120584
#         20        20211215f161149_benchmark_dataset_scratch           225.908787
#         30        20211215f161223_benchmark_dataset_scratch            50.423856
#         40        20211215f161332_benchmark_dataset_scratch            46.694472
#         50        20211215f161455_benchmark_dataset_scratch            49.216037
#         60        20211215f161631_benchmark_dataset_scratch            89.803088
#         80        20211215f161800_benchmark_dataset_scratch            74.782222

# %%
display(get_thread_stats(df_dataset, group_by=group_by_dataset))
# Out:
#                  time_start_thread  time_end_thread  total_elapsed_thread  \
# threading_ident
# 139622935216960       1.639581e+09     1.639581e+09              5.342048
# 139623535235904       1.639581e+09     1.639581e+09              8.585047
# 139624275977024       1.639581e+09     1.639581e+09              6.128909
# 139626875941696       1.639580e+09     1.639580e+09             28.138056
# 139629090493248       1.639580e+09     1.639580e+09             27.921561
# ...                            ...              ...                   ...
# 140717699892032       1.639581e+09     1.639581e+09              5.683332
# 140717927961408       1.639580e+09     1.639580e+09             34.042175
# 140718482367296       1.639580e+09     1.639581e+09             14.213049
# 140718798115648       1.639582e+09     1.639582e+09              0.147819
# 140720103490368       1.639581e+09     1.639581e+09              4.434060
#
#                  dataset  pool_size  elapsed_thread  elapsed_processing
# threading_ident
# 139622935216960  scratch         40        5.367596            0.995240
# 139623535235904       s3         60        8.592311            0.999155
# 139624275977024       s3         80        6.135084            0.998994
# 139626875941696       s3         30       28.184117            0.998366
# 139629090493248       s3         30       28.105643            0.993450
# ...                  ...        ...             ...                 ...
# 140717699892032       s3         80        5.691628            0.998542
# 140717927961408       s3         20       34.088720            0.998635
# 140718482367296       s3         50       14.223160            0.999289
# 140718798115648  scratch         80        0.150339            0.983234
# 140720103490368  scratch         50        4.442804            0.998032
#
# [663 rows x 7 columns]

# %%
plot_all(df_dataset, "__getitem__", plot_max=True, log_scale=True, figsize = (50, 80), group_by=group_by_dataset)

# %%
def plot_throughput_per_storage2(df, group_by: List[str]):
    collected = {}

    x_label = group_by[1]

    df_for_function_name = df[df["function_name"] == "__getitem__"]
    df_for_function_name["request_time"] = df_for_function_name["time_end"] - df_for_function_name["time_start"]
    nodes = set(df_for_function_name["node"].drop_duplicates().tolist())
    df_grouped_by_run = df_for_function_name.groupby(["run"]).agg(
        {"time_start": "min", "time_end": "max", "len": "sum", **{k: "first" for k in group_by}}
    )
    df_grouped_by_run["runtime"] = df_grouped_by_run["time_end"] - df_grouped_by_run["time_start"]
    df_grouped_by_run["throughput [Mbit/s]"] = df_grouped_by_run["len"] / df_grouped_by_run["runtime"] / 10 ** 6 * 8

    # sum of all runtimes and all downloaded data by summer over runs
    df_aggregated_over_runs = df_grouped_by_run.groupby(group_by).agg(
        **{
            "len": ("len", "sum"),
            "runtime": ("runtime", "sum"),
            "min_throughput": ("throughput [Mbit/s]", "min"),
            "max_throughput": ("throughput [Mbit/s]", "max"),
            **{k: (k, "first") for k in group_by},
        }
    )

    # https://en.wikipedia.org/wiki/Data-rate_units#Megabit_per_second
    df_aggregated_over_runs["throughput [Mbit/s]"] = (
        df_aggregated_over_runs["len"] / df_aggregated_over_runs["runtime"] / 10 ** 6 * 8
    )
    df_aggregated_over_runs["min_throughput"] = df_aggregated_over_runs["min_throughput"]

    # all requests from all data
    df_aggregated_over_requests = df_for_function_name.groupby(group_by).agg(
        **{
            "min_request_time": ("request_time", "min"),
            "max_request_time": ("request_time", "max"),
            "median_request_time": ("request_time", "median"),
            "mean_request_time": ("request_time", "mean"),
            **{k: (k, "first") for k in group_by},
        }
    )

    fig, ax1 = plt.subplots(figsize=(15, 5))
    ax1.set_ylim([0, max(200, df_grouped_by_run["throughput [Mbit/s]"].max())])
    ax2 = ax1.twinx()
    cmap = plt.cm.get_cmap("Set1")

    result = []
    # TODO loop over groups instead
    for i, dataset in enumerate(["s3", "scratch"]):
        df = df_aggregated_over_runs[df_aggregated_over_runs["dataset"] == dataset]

        storage = dataset

        ax1.plot(
            df[x_label],
            df["throughput [Mbit/s]"],
            linewidth=2,
            color=cmap(i),
            label=f"{storage} throughput over all runs, min/max hull per run",
        )
        ax1.fill_between(
            df[x_label], df["min_throughput"], df["max_throughput"], color=lighten_color(cmap(i), 0.2), alpha=0.5
        )
        ax1.set_xticks(df[x_label])

        df2 = df_aggregated_over_requests[df_aggregated_over_requests["dataset"] == dataset]
        ax2.plot(
            df2[x_label],
            df2["median_request_time"],
            linewidth=2,
            color=cmap(i),
            label=f"{storage} request_time",
            linestyle="dashed",
        )
        # result.append({str(dataset): [df["throughput [Mbit/s]"], df2["median_request_time"]]})
        result.append({"dataset": dataset, "throughput": df["throughput [Mbit/s]"], "median_request_time": df2["median_request_time"]})

    fig.legend(loc="lower center",  bbox_to_anchor=(0.5, -0.2, 0, 0))

    ax1.set_ylabel("throughput [Mbit/s]")
    ax1.set_xlabel(f"{x_label} [#processes]")
#     ax1.set_title(f"Storage benchmarking {nodes} {list(collected.keys())}")
    ax2.set_ylabel("Request time [s]")
    return result

# %%
thr = plot_throughput_per_storage2(df_dataset, group_by_dataset)

# %%
runs = np.unique(df_dataset["run"])
runs
# Out:
# array(['20211215f153749_benchmark_dataset_s3',
#        '20211215f154403_benchmark_dataset_s3',
#        '20211215f154716_benchmark_dataset_s3',
#        '20211215f154928_benchmark_dataset_s3',
#        '20211215f155109_benchmark_dataset_s3',
#        '20211215f155235_benchmark_dataset_s3',
#        '20211215f155351_benchmark_dataset_s3',
#        '20211215f155500_benchmark_dataset_s3',
#        '20211215f155600_benchmark_dataset_s3',
#        '20211215f155702_benchmark_dataset_s3',
#        '20211215f155808_benchmark_dataset_s3',
#        '20211215f155926_benchmark_dataset_s3',
#        '20211215f160057_benchmark_dataset_s3',
#        '20211215f160239_benchmark_dataset_s3',
#        '20211215f160427_benchmark_dataset_s3',
#        '20211215f160641_benchmark_dataset_scratch',
#        '20211215f160656_benchmark_dataset_scratch',
#        '20211215f160708_benchmark_dataset_scratch',
#        '20211215f160733_benchmark_dataset_scratch',
#        '20211215f160808_benchmark_dataset_scratch',
#        '20211215f160848_benchmark_dataset_scratch',
#        '20211215f160929_benchmark_dataset_scratch',
#        '20211215f161014_benchmark_dataset_scratch',
#        '20211215f161101_benchmark_dataset_scratch',
#        '20211215f161149_benchmark_dataset_scratch',
#        '20211215f161223_benchmark_dataset_scratch',
#        '20211215f161332_benchmark_dataset_scratch',
#        '20211215f161455_benchmark_dataset_scratch',
#        '20211215f161631_benchmark_dataset_scratch',
#        '20211215f161800_benchmark_dataset_scratch'], dtype=object)

# %% [markdown]
#  In the following plot we see that, time and time again, there are requests taking much longer than the median. So we must be prepared for those.
#
#  - scratch: Not sure what happens at the beginning and the end (concavity), whether this happens in all experiments.
#  - s3: the first item always takes much longer (is this at the thread pool or network request level?
# We should find an explanation for those phenomena.

# %%
rts = []
for experiment in runs:
    fig, (ax1, ax2, ax3) = plt.subplots(figsize=(15, 7), nrows=1, ncols=3)
    output_base_folder_timeline_dataset = output_base_folder / experiment
    with (output_base_folder_timeline_dataset / "metadata.json").open() as f:
        metadata = json.load(f)
#     print(metadata["pool_size"])
    df = df_dataset[df_dataset["run"]==experiment]
    df = df[df["function_name"]=="__getitem__"]
    # display(df.head())
    # assert len(df) == metadata["num_get_random_item"], (len(df),metadata["num_get_random_item"])

    if metadata['dataset'] == "s3":
        lim = [0, 1.5]
    else:
        lim = [0, 0.25]
    
#     df["timestamp_index"] = df.index
    rt = df["time_end"].max() - df["time_end"].min()
    rts.append(rt)
    df.plot.scatter(x="time_end", 
            y="elapsed", 
            ylim=lim,
            title=f"Pool size: {metadata['pool_size']}, storage: {metadata['dataset']}, \n runtime: {rt:0.2f} S", ax=ax1)   
    
    x_ticks = np.arange(df["time_end"].min(), df["time_end"].max()+1, 100.0)
    
#     bins = min(int(df["time_end"].max()-df["time_start"].min())*10, 400)
    bins = 400
#     print(f"Bins: {bins} ... {metadata['pool_size']}, storage: {metadata['dataset']}")
    
    df.hist(column="time_end", bins=bins, ax=ax2)
    ax2.axvline(df["time_start"].min(), color="red")
    ax2.axvline(df["time_end"].max(), color="red")
    ax2.set_title(f"time_end, bins: {bins}")


    df.hist(column="time_start", bins=bins, ax=ax3)
    ax3.axvline(df["time_start"].min(), color="red")
    ax3.axvline(df["time_end"].max(), color="red")
    ax3.set_title(f"time_start, bins: {bins}")
    
    ax1.set_xticks(x_ticks)
    ax2.set_xticks(x_ticks)
    ax3.set_xticks(x_ticks)
    
#     break
# Out:
# /tmp/ipykernel_44163/1028212758.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, (ax1, ax2, ax3) = plt.subplots(figsize=(15, 7), nrows=1, ncols=3)

# %%
x_vals = thr[0]['throughput'].keys().get_level_values('pool_size').tolist()
plt.plot(x_vals, rts[:15])
plt.xticks(x_vals)
plt.xlabel("multithreading pool size [#]")
plt.ylabel("experiment duration [S]")
# Out:
# Text(0, 0.5, 'experiment duration [S]')

# %%
x_vals = thr[0]['throughput'].keys().get_level_values('pool_size').tolist()
plt.plot(x_vals, rts[15:])
plt.xticks(x_vals)
plt.xlabel("multithreading pool size [#]")
plt.ylabel("experiment duration [S]")
# Out:
# Text(0, 0.5, 'experiment duration [S]')
