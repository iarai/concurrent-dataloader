# %%
from analysis.analyze_results import *
from pathlib import Path
import matplotlib

# %%
# output_base_folder = Path("/Users/che/iarai/work/logs/storage_benchmarking")
# output_base_folder = Path("/iarai/work/logs/storage_benchmarking")
output_base_folder = Path("/home/ivan/temp/temp-benchmarking")

# %% [markdown]
# ## Dataloader benchmark

# %% [markdown]
# **parameters**
#
# | param | range |
# | --- | --- |
# | batch_pool_size | 2, 4, 8, 16, 32, 64 |
# | num_fetch_workers | 2, 4, 8, 16, 32, 64, 128 |
# | fetch_impl | asyncio, threaded |
# | dataset | s3,scratch |

# %% [markdown]
# **parameters explained**
#
# | param | implementation | details |
# | --- | --- | --- |
# | batch_pool_size | asyncio | Unused |
# |  | threaded | Number of batches to fetch in parallel (normally, one batch is fetched, and items are downloaded (sequentiall or in parallel). This implementation takes N batches, and starts downloading items in parallel. Individual items are yielded and once a full batch is collected it is yielded.)|
# | num_fetch_workers | asyncio | ThreadPoolExecutor argument for the maximum number of threads that can be used to execute the given calls. Also, the number of tasks initiall placed into the task (worker) queue.  |
# |  | threaded | ThreadPoolExecutor argument for the maximum number of threads that can be used to execute the given calls |

# %%
group_by_dataloader = ["dataset",  "num_fetch_workers", "num_workers", "batch_pool"]

# %%
df_dataloader = extract_pandas(output_base_folder, folder_filter="fetcher_impl_5/*benchmark_dataloader_s3*")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 126/126 [00:04<00:00, 26.42it/s]

# %%
df_dataloader_zeroworkers_aio=df_dataloader[df_dataloader["num_workers"]==0]
df_dataloader_zeroworkers_aio=df_dataloader_zeroworkers_aio[df_dataloader_zeroworkers_aio["fetch_impl"]=="asyncio"]

# %%
print(df_dataloader_zeroworkers_aio.groupby(group_by_dataloader).groups.keys())
# Out:
# dict_keys([('s3', 2, 0, 2), ('s3', 2, 0, 4), ('s3', 2, 0, 8), ('s3', 2, 0, 16), ('s3', 2, 0, 32), ('s3', 2, 0, 64), ('s3', 4, 0, 2), ('s3', 4, 0, 4), ('s3', 4, 0, 8), ('s3', 4, 0, 16), ('s3', 4, 0, 32), ('s3', 4, 0, 64), ('s3', 8, 0, 2), ('s3', 8, 0, 4), ('s3', 8, 0, 8), ('s3', 8, 0, 16), ('s3', 8, 0, 32), ('s3', 8, 0, 64), ('s3', 16, 0, 2), ('s3', 16, 0, 4), ('s3', 16, 0, 8), ('s3', 16, 0, 16), ('s3', 16, 0, 32), ('s3', 16, 0, 64), ('s3', 32, 0, 2), ('s3', 32, 0, 4), ('s3', 32, 0, 8), ('s3', 32, 0, 16), ('s3', 32, 0, 32), ('s3', 32, 0, 64), ('s3', 64, 0, 2), ('s3', 64, 0, 4), ('s3', 64, 0, 8), ('s3', 64, 0, 16), ('s3', 64, 0, 32), ('s3', 64, 0, 64), ('s3', 128, 0, 2), ('s3', 128, 0, 4), ('s3', 128, 0, 8), ('s3', 128, 0, 16), ('s3', 128, 0, 32), ('s3', 128, 0, 64)])

# %%
display(get_run_stats(df_dataloader_zeroworkers_aio, group_by=group_by_dataloader))
# Out:
#                                                                                                      downloaded data [B]  \
# dataset num_fetch_workers num_workers batch_pool run
# s3      2                 0           2          20210927f
#                                       16         20210927f130544_benchmark_dataloader_s3_128_0_1...            45.703550
#                                       32         20210927f130748_benchmark_dataloader_s3_128_0_1...            47.686837
#                                       64         20210927f130952_benchmark_dataloader_s3_128_0_1...            47.359702

# %%
display(get_thread_stats(df_dataloader_zeroworkers_aio,group_by=group_by_dataloader))
# Out:
#                  time_start_thread  time_end_thread  total_elapsed_thread  \
# threading_ident
# 139613062551296       1.632741e+09     1.632741e+09             38.600866
# 139613070944000       1.632741e+09     1.632741e+09             39.367376
# 139613079336704       1.632741e+09     1.632741e+09             40.374284
# 139613565851392       1.632741e+09     1.632741e+09             38.127644
# 139613574244096       1.632741e+09     1.632741e+09             42.440383
# ...                            ...              ...                   ...
# 140670975710976       1.632740e+09     1.632740e+09             30.040835
# 140681430320896       1.632738e+09     1.632738e+09            117.463224
# 140681438713600       1.632738e+09     1.632738e+09            118.494779
# 140681447106304       1.632738e+09     1.632738e+09            117.747396
# 140681489053440       1.632738e+09     1.632738e+09            118.197954
#
#                 dataset  num_fetch_workers  num_workers  batch_pool  \
# threading_ident
# 139613062551296      s3                128            0          32
# 139613070944000      s3                128            0          32
# 139613079336704      s3                128            0          32
# 139613565851392      s3                128            0          32
# 139613574244096      s3                128            0          32
# ...                 ...                ...          ...         ...
# 140670975710976      s3                 64            0          16
# 140681430320896      s3                  4            0          32
# 140681438713600      s3                  4            0          32
# 140681447106304      s3                  4            0          32
# 140681489053440      s3                  4            0          32
#
#                  elapsed_thread  elapsed_processing
# threading_ident
# 139613062551296       56.428107            0.684072
# 139613070944000       57.158695            0.688738
# 139613079336704       56.818693            0.710581
# 139613565851392       56.316484            0.677025
# 139613574244096       57.431674            0.738972
# ...                         ...                 ...
# 140670975710976       45.567858            0.659255
# 140681430320896      119.948007            0.979285
# 140681438713600      119.964556            0.987748
# 140681447106304      119.887138            0.982152
# 140681489053440      120.061519            0.984478
#
# [1524 rows x 9 columns]

# %% [markdown]
# ### Event plots of dataloading

# %% [markdown]
# Let's visualize the timeline of dataloading, a new color for each thread (cycle 8)

# %%
df_dataloader_zeroworkers_aio[(df_dataloader_zeroworkers_aio["num_fetch_workers"]==2) & (df_dataloader_zeroworkers_aio["batch_pool"]==4)]["run"].iloc[0]
# Out:
# '20210927f112220_benchmark_dataloader_s3_128_0_2_sync'

# %%
# rate_matrix = np.ndarray(shape=(6,7), dtype=float, order='F')
rate_matrix_asyncio = pd.DataFrame(columns=["x", "y", "rate"])

for i, batch_pool_size in enumerate([2, 4, 8, 16, 32, 64]):
    for j, num_fetch_workers in enumerate([2, 4, 8, 16, 32, 64, 128]):
        print(f"Batch pool size: {num_fetch_workers}, {batch_pool_size}")
        run = df_dataloader_zeroworkers_aio[(df_dataloader_zeroworkers_aio["num_fetch_workers"]==num_fetch_workers) & (df_dataloader_zeroworkers_aio["batch_pool"]==batch_pool_size)]["run"].iloc[0]
        mbps, mbitps = plot_events_timeline(df_dataloader_zeroworkers_aio[df_dataloader_zeroworkers_aio["run"]==run], summary_only=True)
        r = float(list(mbitps)[0].replace("MB", ""))
        rate_matrix_asyncio = rate_matrix_asyncio.append({'x': batch_pool_size, 'y': num_fetch_workers, 'rate': r}, ignore_index=True)
#         rate_matrix[i][j] = float(list(mbps)[0].replace("MB", ""))
print(rate_matrix_asyncio)
# Out:
# Batch pool size: 2, 2
# total_elapsed=0:04:01.877478
# total_bytes=337.4 MB
# overall rate {'1.4 MB'}/s
# overall rate {'11.2 MB'}it/s
# Batch pool size: 4, 2
# total_elapsed=0:02:00.133929
# total_bytes=341.3 MB
# overall rate {'2.8 MB'}/s
# overall rate {'22.7 MB'}it/s
# Batch pool size: 8, 2
# total_elapsed=0:01:04.291563
# total_bytes=341.6 MB
# overall rate {'5.3 MB'}/s
# overall rate {'42.5 MB'}it/s
# Batch pool size: 16, 2
# total_elapsed=0:00:40.359640
# total_bytes=341.6 MB
# overall rate {'8.5 MB'}/s
# overall rate {'67.7 MB'}it/s
# Batch pool size: 32, 2
# total_elapsed=0:00:41.302288
# total_bytes=352.6 MB
# overall rate {'8.5 MB'}/s
# overall rate {'68.3 MB'}it/s
# Batch pool size: 64, 2
# total_elapsed=0:00:46.480745
# total_bytes=354.0 MB
# overall rate {'7.6 MB'}/s
# overall rate {'60.9 MB'}it/s
# Batch pool size: 128, 2
# total_elapsed=0:00:58.643691
# total_bytes=343.2 MB
# overall rate {'5.9 MB'}/s
# overall rate {'46.8 MB'}it/s
# Batch pool size: 2, 4
# total_elapsed=0:03:57.493772
# total_bytes=347.3 MB
# overall rate {'1.5 MB'}/s
# overall rate {'11.7 MB'}it/s
# Batch pool size: 4, 4
# total_elapsed=0:02:00.589266
# total_bytes=337.2 MB
# overall rate {'2.8 MB'}/s
# overall rate {'22.4 MB'}it/s
# Batch pool size: 8, 4
# total_elapsed=0:01:19.053444
# total_bytes=336.0 MB
# overall rate {'4.3 MB'}/s
# overall rate {'34.0 MB'}it/s
# Batch pool size: 16, 4
# total_elapsed=0:00:42.045619
# total_bytes=343.7 MB
# overall rate {'8.2 MB'}/s
# overall rate {'65.4 MB'}it/s
# Batch pool size: 32, 4
# total_elapsed=0:00:40.193650
# total_bytes=352.3 MB
# overall rate {'8.8 MB'}/s
# overall rate {'70.1 MB'}it/s
# Batch pool size: 64, 4
# total_elapsed=0:00:45.689851
# total_bytes=344.6 MB
# overall rate {'7.5 MB'}/s
# overall rate {'60.3 MB'}it/s
# Batch pool size: 128, 4
# total_elapsed=0:00:58.380759
# total_bytes=342.5 MB
# overall rate {'5.9 MB'}/s
# overall rate {'46.9 MB'}it/s
# Batch pool size: 2, 8
# total_elapsed=0:03:59.324407
# total_bytes=344.1 MB
# overall rate {'1.4 MB'}/s
# overall rate {'11.5 MB'}it/s
# Batch pool size: 4, 8
# total_elapsed=0:02:00.476034
# total_bytes=350.7 MB
# overall rate {'2.9 MB'}/s
# overall rate {'23.3 MB'}it/s
# Batch pool size: 8, 8
# total_elapsed=0:01:03.899349
# total_bytes=341.6 MB
# overall rate {'5.3 MB'}/s
# overall rate {'42.8 MB'}it/s
# Batch pool size: 16, 8
# total_elapsed=0:00:41.435592
# total_bytes=362.9 MB
# overall rate {'8.8 MB'}/s
# overall rate {'70.1 MB'}it/s
# Batch pool size: 32, 8
# total_elapsed=0:00:44.587923
# total_bytes=336.0 MB
# overall rate {'7.5 MB'}/s
# overall rate {'60.3 MB'}it/s
# Batch pool size: 64, 8
# total_elapsed=0:00:45.198885
# total_bytes=338.1 MB
# overall rate {'7.5 MB'}/s
# overall rate {'59.8 MB'}it/s
# Batch pool size: 128, 8
# total_elapsed=0:00:57.246628
# total_bytes=349.9 MB
# overall rate {'6.1 MB'}/s
# overall rate {'48.9 MB'}it/s
# Batch pool size: 2, 16
# total_elapsed=0:03:57.342687
# total_bytes=353.4 MB
# overall rate {'1.5 MB'}/s
# overall rate {'11.9 MB'}it/s
# Batch pool size: 4, 16
# total_elapsed=0:01:59.820135
# total_bytes=343.7 MB
# overall rate {'2.9 MB'}/s
# overall rate {'22.9 MB'}it/s
# Batch pool size: 8, 16
# total_elapsed=0:01:03.416737
# total_bytes=346.1 MB
# overall rate {'5.5 MB'}/s
# overall rate {'43.7 MB'}it/s
# Batch pool size: 16, 16
# total_elapsed=0:00:40.904546
# total_bytes=333.4 MB
# overall rate {'8.2 MB'}/s
# overall rate {'65.2 MB'}it/s
# Batch pool size: 32, 16
# total_elapsed=0:00:36.586800
# total_bytes=339.7 MB
# overall rate {'9.3 MB'}/s
# overall rate {'74.3 MB'}it/s
# Batch pool size: 64, 16
# total_elapsed=0:00:45.970031
# total_bytes=334.1 MB
# overall rate {'7.3 MB'}/s
# overall rate {'58.1 MB'}it/s
# Batch pool size: 128, 16
# total_elapsed=0:00:59.648479
# total_bytes=340.8 MB
# overall rate {'5.7 MB'}/s
# overall rate {'45.7 MB'}it/s
# Batch pool size: 2, 32
# total_elapsed=0:03:55.318899
# total_bytes=337.4 MB
# overall rate {'1.4 MB'}/s
# overall rate {'11.5 MB'}it/s
# Batch pool size: 4, 32
# total_elapsed=0:02:00.086053
# total_bytes=348.5 MB
# overall rate {'2.9 MB'}/s
# overall rate {'23.2 MB'}it/s
# Batch pool size: 8, 32
# total_elapsed=0:01:03.879189
# total_bytes=351.1 MB
# overall rate {'5.5 MB'}/s
# overall rate {'44.0 MB'}it/s
# Batch pool size: 16, 32
# total_elapsed=0:00:40.950915
# total_bytes=346.9 MB
# overall rate {'8.5 MB'}/s
# overall rate {'67.8 MB'}it/s
# Batch pool size: 32, 32
# total_elapsed=0:00:40.024738
# total_bytes=332.8 MB
# overall rate {'8.3 MB'}/s
# overall rate {'66.5 MB'}it/s
# Batch pool size: 64, 32
# total_elapsed=0:00:45.508265
# total_bytes=332.7 MB
# overall rate {'7.3 MB'}/s
# overall rate {'58.5 MB'}it/s
# Batch pool size: 128, 32
# total_elapsed=0:00:57.673967
# total_bytes=343.8 MB
# overall rate {'6.0 MB'}/s
# overall rate {'47.7 MB'}it/s
# Batch pool size: 2, 64
# total_elapsed=0:03:54.323628
# total_bytes=336.1 MB
# overall rate {'1.4 MB'}/s
# overall rate {'11.5 MB'}it/s
# Batch pool size: 4, 64
# total_elapsed=0:01:59.955524
# total_bytes=341.2 MB
# overall rate {'2.8 MB'}/s
# overall rate {'22.8 MB'}it/s
# Batch pool size: 8, 64
# total_elapsed=0:01:03.319599
# total_bytes=332.6 MB
# overall rate {'5.3 MB'}/s
# overall rate {'42.0 MB'}it/s
# Batch pool size: 16, 64
# total_elapsed=0:00:41.509169
# total_bytes=359.4 MB
# overall rate {'8.7 MB'}/s
# overall rate {'69.3 MB'}it/s
# Batch pool size: 32, 64
# total_elapsed=0:00:40.683017
# total_bytes=342.6 MB
# overall rate {'8.4 MB'}/s
# overall rate {'67.4 MB'}it/s
# Batch pool size: 64, 64
# total_elapsed=0:00:48.903505
# total_bytes=342.9 MB
# overall rate {'7.0 MB'}/s
# overall rate {'56.1 MB'}it/s
# Batch pool size: 128, 64
# total_elapsed=0:00:58.808198
# total_bytes=348.1 MB
# overall rate {'5.9 MB'}/s
# overall rate {'47.4 MB'}it/s
#        x      y  rate
# 0    2.0    2.0  11.2
# 1    2.0    4.0  22.7
# 2    2.0    8.0  42.5
# 3    2.0   16.0  67.7
# 4    2.0   32.0  68.3
# 5    2.0   64.0  60.9
# 6    2.0  128.0  46.8
# 7    4.0    2.0  11.7
# 8    4.0    4.0  22.4
# 9    4.0    8.0  34.0
# 10   4.0   16.0  65.4
# 11   4.0   32.0  70.1
# 12   4.0   64.0  60.3
# 13   4.0  128.0  46.9
# 14   8.0    2.0  11.5
# 15   8.0    4.0  23.3
# 16   8.0    8.0  42.8
# 17   8.0   16.0  70.1
# 18   8.0   32.0  60.3
# 19   8.0   64.0  59.8
# 20   8.0  128.0  48.9
# 21  16.0    2.0  11.9
# 22  16.0    4.0  22.9
# 23  16.0    8.0  43.7
# 24  16.0   16.0  65.2
# 25  16.0   32.0  74.3
# 26  16.0   64.0  58.1
# 27  16.0  128.0  45.7
# 28  32.0    2.0  11.5
# 29  32.0    4.0  23.2
# 30  32.0    8.0  44.0
# 31  32.0   16.0  67.8
# 32  32.0   32.0  66.5
# 33  32.0   64.0  58.5
# 34  32.0  128.0  47.7
# 35  64.0    2.0  11.5
# 36  64.0    4.0  22.8
# 37  64.0    8.0  42.0
# 38  64.0   16.0  69.3
# 39  64.0   32.0  67.4
# 40  64.0   64.0  56.1
# 41  64.0  128.0  47.4

# %%
df_dataloader_zeroworkers_th=df_dataloader[df_dataloader["num_workers"]==0]
df_dataloader_zeroworkers_th=df_dataloader_zeroworkers_th[df_dataloader_zeroworkers_th["fetch_impl"]=="threaded"]

# %%
display(get_run_stats(df_dataloader_zeroworkers_th, group_by=group_by_dataloader))
# Out:
#                                                                                                      downloaded data [B]  \
# dataset num_fetch_workers num_workers batch_pool run
# s3      2                 0           2          20210927f111146_benchmark_dataloader_s3_128_0_2...          679592750.0
#                                       4          20210927f111906_benchmark_dataloader_s3_128_0_2...          679083432.0
#                                       8          20210927f112620_benchmark_dataloader_s3_128_0_2...          679083432.0
#                                       16         20210927f113338_benchmark_dataloader_s3_128_0_2...          679083432.0
#                                       32         20210927f114052_benchmark_dataloader_s3_128_0_2...          679083432.0
#                                       64         20210927f114803_benchmark_dataloader_s3_128_0_2...          679083432.0
#         4                 0           2          20210927f115516_benchmark_dataloader_s3_128_0_4...          693855250.0
#                                       4          20210927f115902_benchmark_dataloader_s3_128_0_4...          693855250.0
#         8                 0           2          20210927f121805_benchmark_dataloader_s3_128_0_8...           100.025200
#                                       4          20210927f122010_benchmark_dataloader_s3_128_0_8...            99.641363
#                                       8          20210927f122229_benchmark_dataloader_s3_128_0_8...            99.456232
#                                       16         20210927f122434_benchmark_dataloader_s3_128_0_8...           100.122203
#                                       32         20210927f122638_benchmark_dataloader_s3_128_0_8...            98.507118
#                                       64         20210927f122843_benchmark_dataloader_s3_128_0_8...            99.446910
#         16                0           2          20210927f123048_benchmark_dataloader_s3_128_0_1...           140.335307
#                                       4          20210927f123213_benchmark_dataloader_s3_128_0_1...           146.221580
#                                       8          20210927f123338_benchmark_dataloader_s3_128_0_1...           138.810562
#                                       16         20210927f123504_benchmark_dataloader_s3_128_0_1...           138.334392
#                                       32         20210927f123633_benchmark_dataloader_s3_128_0_1...           141.290975
#                                       64         20210927f123800_benchmark_dataloader_s3_128_0_1...           135.824268
#         32                0           2          20210927f123929_benchmark_dataloader_s3_128_0_3...           129.653229
#                                       4          20210927f124059_benchmark_dataloader_s3_128_0_3...           127.334201
#                                       8          20210927f124229_benchmark_dataloader_s3_128_0_3...           110.145817
#                                       16         20210927f124410_benchmark_dataloader_s3_128_0_3...           121.085124
#                                       32         20210927f124537_benchmark_dataloader_s3_128_0_3...           138.369670
#                                       64         20210927f124702_benchmark_dataloader_s3_128_0_3...           125.534971
#         64                0           2          20210927f124832_benchmark_dataloader_s3_128_0_6...           117.903430
#                                       4          20210927f125011_benchmark_dataloader_s3_128_0_6...           114.376340
#                                       8          20210927f125150_benchmark_dataloader_s3_128_0_6...           115.766689
#                                       16         20210927f125328_benchmark_dataloader_s3_128_0_6...           116.122964
#                                       32         20210927f125507_benchmark_dataloader_s3_128_0_6...           115.353691
#                                       64         20210927f125646_benchmark_dataloader_s3_128_0_6...           112.096511
#         128               0           2          20210927f125830_benchmark_dataloader_s3_128_0_1...            94.775728
#                                       4          20210927f130034_benchmark_dataloader_s3_128_0_1...            92.106231
#                                       8          20210927f130238_benchmark_dataloader_s3_128_0_1...            91.756543
#                                       16         20210927f130442_benchmark_dataloader_s3_128_0_1...            93.590589
#                                       32         20210927f130647_benchmark_dataloader_s3_128_0_1...            93.730705
#                                       64         20210927f130849_benchmark_dataloader_s3_128_0_1...            91.588019

# %%
# rate_matrix = np.ndarray(shape=(6,7), dtype=float, order='F')
rate_matrix_threaded = pd.DataFrame(columns=["x", "y", "rate"])

for i, batch_pool_size in enumerate([2, 4, 8, 16, 32, 64]):
    for j, num_fetch_workers in enumerate([2, 4, 8, 16, 32, 64, 128]):
        print(f"Batch pool size: {num_fetch_workers}, {batch_pool_size}")
        run = df_dataloader_zeroworkers_th[(df_dataloader_zeroworkers_th["num_fetch_workers"]==num_fetch_workers) & (df_dataloader_zeroworkers_th["batch_pool"]==batch_pool_size)]["run"].iloc[0]
        mbps, mbitps = plot_events_timeline(df_dataloader_zeroworkers_th[df_dataloader_zeroworkers_th["run"]==run], summary_only=True)
        if list(mbitps)[0] != "0 Bytes":
            r = float(list(mbitps)[0].replace("MB", ""))
            rate_matrix_threaded = rate_matrix_threaded.append({'x': batch_pool_size, 'y': num_fetch_workers, 'rate': r}, ignore_index=True)
#         rate_matrix[i][j] = float(list(mbps)[0].replace("MB", ""))
print(rate_matrix_threaded)
# Out:
# Batch pool size: 2, 2
# total_elapsed=0:03:12.342901
# total_bytes=679.6 MB
# overall rate {'3.5 MB'}/s
# overall rate {'28.3 MB'}it/s
# Batch pool size: 4, 2
# total_elapsed=0:01:40.820240
# total_bytes=693.9 MB
# overall rate {'6.9 MB'}/s
# overall rate {'55.1 MB'}it/s
# Batch pool size: 8, 2
# total_elapsed=0:00:55.494436
# total_bytes=693.9 MB
# overall rate {'12.5 MB'}/s
# overall rate {'100.0 MB'}it/s
# Batch pool size: 16, 2
# total_elapsed=0:00:39.554137
# total_bytes=693.9 MB
# overall rate {'17.5 MB'}/s
# overall rate {'140.3 MB'}it/s
# Batch pool size: 32, 2
# total_elapsed=0:00:42.812987
# total_bytes=693.9 MB
# overall rate {'16.2 MB'}/s
# overall rate {'129.7 MB'}it/s
# Batch pool size: 64, 2
# total_elapsed=0:00:47.079563
# total_bytes=693.9 MB
# overall rate {'14.7 MB'}/s
# overall rate {'117.9 MB'}it/s
# Batch pool size: 128, 2
# total_elapsed=0:00:58.568181
# total_bytes=693.9 MB
# overall rate {'11.8 MB'}/s
# overall rate {'94.8 MB'}it/s
# Batch pool size: 2, 4
# total_elapsed=0:03:11.192951
# total_bytes=679.1 MB
# overall rate {'3.6 MB'}/s
# overall rate {'28.4 MB'}it/s
# Batch pool size: 4, 4
# total_elapsed=0:01:42.133414
# total_bytes=693.9 MB
# overall rate {'6.8 MB'}/s
# overall rate {'54.3 MB'}it/s
# Batch pool size: 8, 4
# total_elapsed=0:00:55.708210
# total_bytes=693.9 MB
# overall rate {'12.5 MB'}/s
# overall rate {'99.6 MB'}it/s
# Batch pool size: 16, 4
# total_elapsed=0:00:37.961852
# total_bytes=693.9 MB
# overall rate {'18.3 MB'}/s
# overall rate {'146.2 MB'}it/s
# Batch pool size: 32, 4
# total_elapsed=0:00:43.592703
# total_bytes=693.9 MB
# overall rate {'15.9 MB'}/s
# overall rate {'127.3 MB'}it/s
# Batch pool size: 64, 4
# total_elapsed=0:00:48.531383
# total_bytes=693.9 MB
# overall rate {'14.3 MB'}/s
# overall rate {'114.4 MB'}it/s
# Batch pool size: 128, 4
# total_elapsed=0:01:00.265651
# total_bytes=693.9 MB
# overall rate {'11.5 MB'}/s
# overall rate {'92.1 MB'}it/s
# Batch pool size: 2, 8
# total_elapsed=0:03:12.878572
# total_bytes=679.1 MB
# overall rate {'3.5 MB'}/s
# overall rate {'28.2 MB'}it/s
# Batch pool size: 4, 8
# total_elapsed=0:01:47.508066
# total_bytes=690.0 MB
# overall rate {'6.4 MB'}/s
# overall rate {'51.3 MB'}it/s
# Batch pool size: 8, 8
# total_elapsed=0:00:55.811907
# total_bytes=693.9 MB
# overall rate {'12.4 MB'}/s
# overall rate {'99.5 MB'}it/s
# Batch pool size: 16, 8
# total_elapsed=0:00:39.988614
# total_bytes=693.9 MB
# overall rate {'17.4 MB'}/s
# overall rate {'138.8 MB'}it/s
# Batch pool size: 32, 8
# total_elapsed=0:00:50.395395
# total_bytes=693.9 MB
# overall rate {'13.8 MB'}/s
# overall rate {'110.1 MB'}it/s
# Batch pool size: 64, 8
# total_elapsed=0:00:47.948525
# total_bytes=693.9 MB
# overall rate {'14.5 MB'}/s
# overall rate {'115.8 MB'}it/s
# Batch pool size: 128, 8
# total_elapsed=0:01:00.495326
# total_bytes=693.9 MB
# overall rate {'11.5 MB'}/s
# overall rate {'91.8 MB'}it/s
# Batch pool size: 2, 16
# total_elapsed=0:03:10.914865
# total_bytes=679.1 MB
# overall rate {'3.6 MB'}/s
# overall rate {'28.5 MB'}it/s
# Batch pool size: 4, 16
# total_elapsed=0:01:41.261398
# total_bytes=693.9 MB
# overall rate {'6.9 MB'}/s
# overall rate {'54.8 MB'}it/s
# Batch pool size: 8, 16
# total_elapsed=0:00:55.440670
# total_bytes=693.9 MB
# overall rate {'12.5 MB'}/s
# overall rate {'100.1 MB'}it/s
# Batch pool size: 16, 16
# total_elapsed=0:00:40.126262
# total_bytes=693.9 MB
# overall rate {'17.3 MB'}/s
# overall rate {'138.3 MB'}it/s
# Batch pool size: 32, 16
# total_elapsed=0:00:45.842477
# total_bytes=693.9 MB
# overall rate {'15.1 MB'}/s
# overall rate {'121.1 MB'}it/s
# Batch pool size: 64, 16
# total_elapsed=0:00:47.801415
# total_bytes=693.9 MB
# overall rate {'14.5 MB'}/s
# overall rate {'116.1 MB'}it/s
# Batch pool size: 128, 16
# total_elapsed=0:00:59.309831
# total_bytes=693.9 MB
# overall rate {'11.7 MB'}/s
# overall rate {'93.6 MB'}it/s
# Batch pool size: 2, 32
# total_elapsed=0:03:11.171694
# total_bytes=679.1 MB
# overall rate {'3.6 MB'}/s
# overall rate {'28.4 MB'}it/s
# Batch pool size: 4, 32
# total_elapsed=0:01:41.388615
# total_bytes=693.9 MB
# overall rate {'6.8 MB'}/s
# overall rate {'54.7 MB'}it/s
# Batch pool size: 8, 32
# total_elapsed=0:00:56.349654
# total_bytes=693.9 MB
# overall rate {'12.3 MB'}/s
# overall rate {'98.5 MB'}it/s
# Batch pool size: 16, 32
# total_elapsed=0:00:39.286600
# total_bytes=693.9 MB
# overall rate {'17.7 MB'}/s
# overall rate {'141.3 MB'}it/s
# Batch pool size: 32, 32
# total_elapsed=0:00:40.116031
# total_bytes=693.9 MB
# overall rate {'17.3 MB'}/s
# overall rate {'138.4 MB'}it/s
# Batch pool size: 64, 32
# total_elapsed=0:00:48.120194
# total_bytes=693.9 MB
# overall rate {'14.4 MB'}/s
# overall rate {'115.4 MB'}it/s
# Batch pool size: 128, 32
# total_elapsed=0:00:59.221170
# total_bytes=693.9 MB
# overall rate {'11.7 MB'}/s
# overall rate {'93.7 MB'}it/s
# Batch pool size: 2, 64
# total_elapsed=0:03:12.129825
# total_bytes=679.1 MB
# overall rate {'3.5 MB'}/s
# overall rate {'28.3 MB'}it/s
# Batch pool size: 4, 64
# total_elapsed=0:01:41.256091
# total_bytes=693.9 MB
# overall rate {'6.9 MB'}/s
# overall rate {'54.8 MB'}it/s
# Batch pool size: 8, 64
# total_elapsed=0:00:55.817139
# total_bytes=693.9 MB
# overall rate {'12.4 MB'}/s
# overall rate {'99.4 MB'}it/s
# Batch pool size: 16, 64
# total_elapsed=0:00:40.867822
# total_bytes=693.9 MB
# overall rate {'17.0 MB'}/s
# overall rate {'135.8 MB'}it/s
# Batch pool size: 32, 64
# total_elapsed=0:00:44.217495
# total_bytes=693.9 MB
# overall rate {'15.7 MB'}/s
# overall rate {'125.5 MB'}it/s
# Batch pool size: 64, 64
# total_elapsed=0:00:49.518419
# total_bytes=693.9 MB
# overall rate {'14.0 MB'}/s
# overall rate {'112.1 MB'}it/s
# Batch pool size: 128, 64
# total_elapsed=0:01:00.606639
# total_bytes=693.9 MB
# overall rate {'11.4 MB'}/s
# overall rate {'91.6 MB'}it/s
#        x      y   rate
# 0    2.0    2.0   28.3
# 1    2.0    4.0   55.1
# 2    2.0    8.0  100.0
# 3    2.0   16.0  140.3
# 4    2.0   32.0  129.7
# 5    2.0   64.0  117.9
# 6    2.0  128.0   94.8
# 7    4.0    2.0   28.4
# 8    4.0    4.0   54.3
# 9    4.0    8.0   99.6
# 10   4.0   16.0  146.2
# 11   4.0   32.0  127.3
# 12   4.0   64.0  114.4
# 13   4.0  128.0   92.1
# 14   8.0    2.0   28.2
# 15   8.0    4.0   51.3
# 16   8.0    8.0   99.5
# 17   8.0   16.0  138.8
# 18   8.0   32.0  110.1
# 19   8.0   64.0  115.8
# 20   8.0  128.0   91.8
# 21  16.0    2.0   28.5
# 22  16.0    4.0   54.8
# 23  16.0    8.0  100.1
# 24  16.0   16.0  138.3
# 25  16.0   32.0  121.1
# 26  16.0   64.0  116.1
# 27  16.0  128.0   93.6
# 28  32.0    2.0   28.4
# 29  32.0    4.0   54.7
# 30  32.0    8.0   98.5
# 31  32.0   16.0  141.3
# 32  32.0   32.0  138.4
# 33  32.0   64.0  115.4
# 34  32.0  128.0   93.7
# 35  64.0    2.0   28.3
# 36  64.0    4.0   54.8
# 37  64.0    8.0   99.4
# 38  64.0   16.0  135.8
# 39  64.0   32.0  125.5
# 40  64.0   64.0  112.1
# 41  64.0  128.0   91.6

# %%
# rate_matrix_asyncio["rate"] = rate_matrix_asyncio["rate"]# * 10
# rate_matrix_threaded["rate"] = rate_matrix_threaded["rate"]# * 10

# %% [markdown]
# ### Comparison - asyncio vs. threaded
#
# *Bubble plot*
#  - x-axis, batch_pool_size (2, 4, 8, 16, 32, 64)
#  - y-axis, num_fetch_workers (2, 4, 8, 16, 32, 64, 128)
#  - dot-size, rate in mbit/s

# %%
plt.rcParams["figure.figsize"] = (15,15)
ax = plt.gca()
ax.scatter(rate_matrix_asyncio.x, rate_matrix_asyncio.y, s=rate_matrix_asyncio.rate**1.3,
             alpha=0.6, 
             c="green",
             marker='o')
ax.scatter(rate_matrix_threaded.x, rate_matrix_threaded.y, s=rate_matrix_threaded.rate**1.3,
             alpha=0.2, 
             c="blue",
             marker='o')
plt.xlabel("batch_pool_size", size=15)
plt.ylabel("num_fetch_workers", size=15)
plt.title("Threaded [green] vs Asyncio [blue]", size=15)
# Out:
# Text(0.5, 1.0, 'Threaded [green] vs Asyncio [blue]')

# %%
both = pd.concat([rate_matrix_asyncio, rate_matrix_threaded["rate"]], ignore_index = True, axis = 1)
both['diff'] = both.apply(lambda row: float(row[3] - row[2]) , axis = 1)
both.columns = ['x', 'y', 'asyncio', 'threaded', 'diff']
both["diff"] = both["diff"].clip(lower=0)
# both

# %% [markdown]
# Bubble plot shows 3 dimensions, however it's hard to visualize the difference between two approaches, therefore the following bar-plots show each dimension batch_pool_size and num_fetch_workers separately, while the y-axis shows the rate in Mbit/s.
#
# Since it doesn't have any effect for asyncio, those should be roughly the same. However, we can observe that for threaded implementation we have the similar result (Does this mean we don't have a problem with batch-collection order? (e.g. batch 3 is not collected before batch 2))

# %%
plt.rcParams["figure.figsize"] = (10,10)
ax = plt.subplot(111)
ax.bar(x=list(both.x), height=list(both.threaded), width=1, color="red")
ax.bar(x=list(both.x+1), height=list(both.asyncio), width=1, color="blue")
plt.xlabel("batch_pool_size", size=15)
plt.ylabel("mbit/s", size=15)
plt.title("Threaded [red] vs asyncio [blue]", size=15)
# Out:
# Text(0.5, 1.0, 'Threaded [red] vs asyncio [blue]')

# %%
plt.rcParams["figure.figsize"] = (10,10)
ax = plt.subplot(111)
ax.bar(x=list(both.y), height=list(both.threaded), width=1, color="red")
ax.bar(x=list(both.y+1), height=list(both.asyncio), width=1, color="blue")
plt.xlabel("num_fetch_workers", size=15)
plt.ylabel("Mbit/s", size=15)
plt.title("Threaded [red] vs asyncio [blue]", size=15)
# Out:
# Text(0.5, 1.0, 'Threaded [red] vs asyncio [blue]')

# %%
both.sort_values(by=['threaded'], ascending=False)
# x = batch_pool_size, y = num_fetch_workers
# Out:
#        x      y  asyncio  threaded  diff
# 10   4.0   16.0     65.4     146.2  80.8
# 31  32.0   16.0     67.8     141.3  73.5
# 3    2.0   16.0     67.7     140.3  72.6
# 17   8.0   16.0     70.1     138.8  68.7
# 32  32.0   32.0     66.5     138.4  71.9
# 24  16.0   16.0     65.2     138.3  73.1
# 38  64.0   16.0     69.3     135.8  66.5
# 4    2.0   32.0     68.3     129.7  61.4
# 11   4.0   32.0     70.1     127.3  57.2
# 39  64.0   32.0     67.4     125.5  58.1
# 25  16.0   32.0     74.3     121.1  46.8
# 5    2.0   64.0     60.9     117.9  57.0
# 26  16.0   64.0     58.1     116.1  58.0
# 19   8.0   64.0     59.8     115.8  56.0
# 33  32.0   64.0     58.5     115.4  56.9
# 12   4.0   64.0     60.3     114.4  54.1
# 40  64.0   64.0     56.1     112.1  56.0
# 18   8.0   32.0     60.3     110.1  49.8
# 23  16.0    8.0     43.7     100.1  56.4
# 2    2.0    8.0     42.5     100.0  57.5
# 9    4.0    8.0     34.0      99.6  65.6
# 16   8.0    8.0     42.8      99.5  56.7
# 37  64.0    8.0     42.0      99.4  57.4
# 30  32.0    8.0     44.0      98.5  54.5
# 6    2.0  128.0     46.8      94.8  48.0
# 34  32.0  128.0     47.7      93.7  46.0
# 27  16.0  128.0     45.7      93.6  47.9
# 13   4.0  128.0     46.9      92.1  45.2
# 20   8.0  128.0     48.9      91.8  42.9
# 41  64.0  128.0     47.4      91.6  44.2
# 1    2.0    4.0     22.7      55.1  32.4
# 22  16.0    4.0     22.9      54.8  31.9
# 36  64.0    4.0     22.8      54.8  32.0
# 29  32.0    4.0     23.2      54.7  31.5
# 8    4.0    4.0     22.4      54.3  31.9
# 15   8.0    4.0     23.3      51.3  28.0
# 21  16.0    2.0     11.9      28.5  16.6
# 28  32.0    2.0     11.5      28.4  16.9
# 7    4.0    2.0     11.7      28.4  16.7
# 35  64.0    2.0     11.5      28.3  16.8
# 0    2.0    2.0     11.2      28.3  17.1
# 14   8.0    2.0     11.5      28.2  16.7

# %%
import numpy as np
import seaborn as sns
def plot_events_timeline2(df_dataloader, color_column: str = "threading_ident", cycle=11, summary_only=False):
#     df_dataloader = df_dataloader[(df_dataloader["function_name"] == "__getitem__")]
#     print(len(df_dataloader))
#     df_dataloader = df_dataloader[(df_dataloader["process_time"] >= 10.0e-02)]
#     print(len(df_dataloader))

    
    clrz = {}
    x = np.array(list(df_dataloader["threading_ident"]))
    pallete = sns.color_palette(None, len(np.unique(x)))
    for index, t in enumerate(np.unique(x)):
        clrz[t] = pallete[index]
    print(np.unique(x))
#     x = np.array(list(df_dataloader["function_name"]))
#     print(np.unique(x))
#     x = np.array(list(df_dataloader["process_time"]))
#     print(np.unique(x))
    
    df_dataloader = df_dataloader.sort_values(
        ["pid","threading_ident", "process_time"], ascending=[False, False, False]
    ).reset_index(drop=True)
#     print(df_dataloader.info())


#     df_dataloader = df_dataloader.sort_values(["threading_ident","trace_level"], 
#                                               ascending=[False,False]).reset_index(drop=False)
#     df_dataloader = df_dataloader.sort_values(["threading_ident"], ascending=[False])
    

#     df_dataloader = df_dataloader[(df_dataloader["function_name"] == "yield_item")]
    
    k = df_dataloader[(df_dataloader["threading_ident"] == 140691247621888)]
    print(df_dataloader["function_name"])

#     df_dataloader = df_dataloader.sort_values(
#         ["threading_ident", "time_start"], ascending=[False, False]
#     ).reset_index(drop=True)
#     df_dataloader = df_dataloader.groupby(["threading_ident"])

    dict_dataloader = df_dataloader.to_dict("index")
    
    print(len(dict_dataloader.items()))
#     print(list(dict_dataloader)[:10])

#     dict_dataloader = df_dataloader.groupby('threading_ident').apply(pd.DataFrame).to_dict("index")
#     dict_dataloader = dict_dataloader['threading_ident'].reset_index()
#     dict_dataloader = dict_dataloader.set_index('threading_ident')

    colors = []
    lines = []
    for i, (_, param_series) in enumerate(dict_dataloader.items()):
#         colors.append(clrz[param_series["threading_ident"]])
        lines.append([(param_series["process_time_start"], i), (param_series["process_time_end"], i)])
#         lines.append([(param_series["time_start"], i), (param_series["time_end"], i)])
        if param_series["threading_ident"] == 140691247621888:
            colors.append("black")
        else:
            colors.append("red")

    print(f"Lines num: {len(lines)}")
#     for line in list(lines):
#         d = line[1][0] - line[0][0]
#         if d > 5:
#             lines.remove(line)

    lc = matplotlib.collections.LineCollection(lines, colors=colors, linewidths=3)
    fig, ax = plt.subplots(figsize=(50, 50))
    ax.add_collection(lc)
    ax.autoscale()
    ax.margins(0.1)

# %% [markdown]
# ### Threaded best run

# %%
# for i, batch_pool_size in enumerate([2, 4, 8, 16, 32, 64]):
#     for j, num_fetch_workers in enumerate([2, 4, 8, 16, 32, 64, 128]):
run = df_dataloader_zeroworkers_th[(df_dataloader_zeroworkers_th["num_fetch_workers"]==16) & (df_dataloader_zeroworkers_th["batch_pool"]==4)]["run"].iloc[0]
plot_events_timeline2(df_dataloader_zeroworkers_th[df_dataloader_zeroworkers_th["run"]==run], summary_only=False)
# Out:
# [140686393329408 140686410114816 140686418507520 140686770804480
#  140686779197184 140686787589888 140686795982592 140686804375296
#  140686812768000 140686821160704 140687301564160 140687307675392
#  140687309956864 140687316068096 140687318349568 140687324460800
#  140687326742272 140687332853504 140687335134976 140687341246208
#  140687349638912 140687358031616 140687920047872 140687928440576
#  140687936833280 140687945225984 140687953618688 140687962011392
#  140689789282048 140689797674752 140689814460160 140689822852864
#  140690081494784 140690593203968 140690635208448 140690635699968
#  140690637338368 140690637973248 140690638321408 140690638604032
#  140690646488832 140690646714112 140690651936512 140690652485376
#  140690654758656 140690655106816 140690655389440 140690660329216
#  140690663274240 140690663499520 140690665199360 140690669270784
#  140690671666944 140690671892224 140690677663488 140690680059648
#  140690680284928 140690688677632 140690689206016 140690697070336
#  140690705987328 140690828150528 140690832545536 140690836543232
#  140690912044800 140690912102144 140690920437504 140690995939072
#  140690996029184 140690996205312 140691004331776 140691046278912
#  140691088226048 140691130173184 140691172120320 140691247621888
#  140691294762752 140692853770048]
# 5420
# Lines num: 5420

# %% [markdown]
# ### Threaded worst run

# %%
run = df_dataloader_zeroworkers_th[(df_dataloader_zeroworkers_th["num_fetch_workers"]==2) & (df_dataloader_zeroworkers_th["batch_pool"]==8)]["run"].iloc[0]
plot_events_timeline(df_dataloader_zeroworkers_th[df_dataloader_zeroworkers_th["run"]==run], summary_only=False)
# Out:
# total_elapsed=0:03:12.878572
# total_bytes=679.1 MB
# overall rate {'3.5 MB'}/s
# overall rate {'28.2 MB'}it/s

# %% [markdown]
# ### Asyncio best run

# %%
# for i, batch_pool_size in enumerate([2, 4, 8, 16, 32, 64]):
#     for j, num_fetch_workers in enumerate([2, 4, 8, 16, 32, 64, 128]):
run = df_dataloader_zeroworkers_aio[(df_dataloader_zeroworkers_aio["num_fetch_workers"]==32) & (df_dataloader_zeroworkers_aio["batch_pool"]==16)]["run"].iloc[0]
plot_events_timeline(df_dataloader_zeroworkers_aio[df_dataloader_zeroworkers_aio["run"]==run], summary_only=False)
# Out:
# total_elapsed=0:00:36.586800
# total_bytes=339.7 MB
# overall rate {'9.3 MB'}/s
# overall rate {'74.3 MB'}it/s

# %% [markdown]
# ### Asyncio worst run

# %%
run = df_dataloader_zeroworkers_aio[(df_dataloader_zeroworkers_aio["num_fetch_workers"]==2) & (df_dataloader_zeroworkers_aio["batch_pool"]==2)]["run"].iloc[0]
plot_events_timeline(df_dataloader_zeroworkers_aio[df_dataloader_zeroworkers_aio["run"]==run], summary_only=False)
# Out:
# total_elapsed=0:04:01.877478
# total_bytes=337.4 MB
# overall rate {'1.4 MB'}/s
# overall rate {'11.2 MB'}it/s
