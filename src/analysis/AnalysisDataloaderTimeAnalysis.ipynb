# %%
from analysis.analyze_results import *
from pathlib import Path
import matplotlib

# %%
# output_base_folder = Path("/iarai/work/logs/storage_benchmarking")
output_base_folder = Path("/home/ivan/temp/temp-benchmarking")

# %% [markdown]
# ## Dataloader benchmark (num workers, batch size)

# %% [markdown]
# **parameters**
#
# | param | range |
# | --- | --- |
# | num_workers |0, 2, 4, 8, 16 |
# | batch_size | 8, 16, 32, 64 |
# | num_fetch_workers | 4, 8, 16, 32 |
# | fetch_impl | asyncio, threaded |
# | dataset | s3,scratch |
#
# Batch pool size is fixed to 10

# %% [markdown]
# **parameters explained**
#
# | param | implementation | details |
# | --- | --- | --- |
# | batch_pool_size | asyncio | Unused |
# |  | threaded | Number of batches to fetch in parallel (normally, one batch is fetched, and items are downloaded (sequentially or in parallel). This implementation takes N batches and starts downloading items in parallel. Individual items are yielded and once a full batch is collected it is yielded.)|
# | num_fetch_workers | asyncio | ThreadPoolExecutor argument for the maximum number of threads that can be used to execute the given calls. Also, the number of tasks initially placed into the task (worker) queue.  |
# |  | threaded | ThreadPoolExecutor argument for the maximum number of threads that can be used to execute the given calls |

# %%
group_by_dataloader = ["dataset", "batch_size", "fetch_impl", "prefetch_factor"]

# %%
s3_folder_filter="e2e1210/*benchmark_e2e_s3*"

# %%
# df_dataloader_s3_full = extract_pandas(output_base_folder, folder_filter="e2e-vanilla/*benchmark_e2e_s3*")
df_dataloader = extract_pandas(output_base_folder, folder_filter=s3_folder_filter)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1456/1456 [01:26<00:00, 16.88it/s]

# %%
# df_dataloader[df_dataloader["fetch_impl"]=="asyncio"].index
# df_dataloader = df_dataloader[(df_dataloader.fetch_impl == "vanilla") & 
#                               (df_dataloader.fetch_impl == "threaded")]
# df_dataloader[df_dataloader.fetch_impl == "threaded"]
# df_dataloader[df_dataloader.fetch_impl=="vanilla"]

# %%
df_dataloader_async=df_dataloader[df_dataloader["fetch_impl"]=="asyncio"]
df_dataloader = df_dataloader[(df_dataloader.fetch_impl == "vanilla") | 
                              (df_dataloader.fetch_impl == "threaded")]

df_dataloader_threaded=df_dataloader[df_dataloader["fetch_impl"]=="threaded"]
df_dataloader = df_dataloader[(df_dataloader.fetch_impl == "vanilla")]

df_dataloader_vanilla=df_dataloader[df_dataloader["fetch_impl"]=="vanilla"]
del df_dataloader

# %%
df_dataloader_async
# Out:
#                        trace_name  trace_level function_name     elapsed  \
# 0                    (5)-get_item            5   __getitem__   84.968517
# 1                    (5)-get_item            5   __getitem__    0.176355
# 2                    (5)-get_item            5   __getitem__    0.130764
# 3                    (5)-get_item            5   __getitem__    0.132842
# 4                    (5)-get_item            5   __getitem__   86.988160
# ...                           ...          ...           ...         ...
# 1544                 (5)-get_item            5   __getitem__    0.416715
# 1545                 (5)-get_item            5   __getitem__    0.146512
# 1546                 (5)-get_item            5   __getitem__    0.163519
# 1547  (4)-asyncmapdataset-fetcher            4         fetch    1.381122
# 1548              (3)-worker_loop            3  _worker_loop  156.733633
#
#         time_start      time_end  process_time  process_time_start  \
# 0     1.634057e+09  1.634057e+09      2.205517            0.611895
# 1     1.634057e+09  1.634057e+09      0.032036            2.835594
# 2     1.634057e+09  1.634057e+09      0.022257            2.884445
# 3     1.634057e+09  1.634057e+09      0.040348            2.920887
# 4     1.634057e+09  1.634057e+09      2.603598            0.424713
# ...            ...           ...           ...                 ...
# 1544  1.634054e+09  1.634054e+09      0.723778           34.855267
# 1545  1.634054e+09  1.634054e+09      0.223086           35.367429
# 1546  1.634054e+09  1.634054e+09      0.242830           35.358712
# 1547  1.634054e+09  1.634054e+09      2.415785           33.225807
# 1548  1.634054e+09  1.634054e+09     35.700214            0.004234
#
#       process_time_end    pid  ...  momentum  weight_decay  pretrained  \
# 0             2.817412  31141  ...       0.9        0.0001       False
# 1             2.867631  31141  ...       0.9        0.0001       False
# 2             2.906702  31141  ...       0.9        0.0001       False
# 3             2.961235  31141  ...       0.9        0.0001       False
# 4             3.028311  31141  ...       0.9        0.0001       False
# ...                ...    ...  ...       ...           ...         ...
# 1544         35.579044  23470  ...       0.9        0.0001       False
# 1545         35.590515  23470  ...       0.9        0.0001       False
# 1546         35.601542  23470  ...       0.9        0.0001       False
# 1547         35.641591  23470  ...       0.9        0.0001       False
# 1548         35.704448  23470  ...       0.9        0.0001       False
#
#       system        node          release  \
# 0      Linux  lnx-slim-2  4.19.0-14-amd64
# 1      Linux  lnx-slim-2  4.19.0-14-amd64
# 2      Linux  lnx-slim-2  4.19.0-14-amd64
# 3      Linux  lnx-slim-2  4.19.0-14-amd64
# 4      Linux  lnx-slim-2  4.19.0-14-amd64
# ...      ...         ...              ...
# 1544   Linux  lnx-slim-2  4.19.0-14-amd64
# 1545   Linux  lnx-slim-2  4.19.0-14-amd64
# 1546   Linux  lnx-slim-2  4.19.0-14-amd64
# 1547   Linux  lnx-slim-2  4.19.0-14-amd64
# 1548   Linux  lnx-slim-2  4.19.0-14-amd64
#
#                                     version machine  \
# 0     #1 SMP Debian 4.19.171-2 (2021-01-30)  x86_64
# 1     #1 SMP Debian 4.19.171-2 (2021-01-30)  x86_64
# 2     #1 SMP Debian 4.19.171-2 (2021-01-30)  x86_64
# 3     #1 SMP Debian 4.19.171-2 (2021-01-30)  x86_64
# 4     #1 SMP Debian 4.19.171-2 (2021-01-30)  x86_64
# ...                                     ...     ...
# 1544  #1 SMP Debian 4.19.171-2 (2021-01-30)  x86_64
# 1545  #1 SMP Debian 4.19.171-2 (2021-01-30)  x86_64
# 1546  #1 SMP Debian 4.19.171-2 (2021-01-30)  x86_64
# 1547  #1 SMP Debian 4.19.171-2 (2021-01-30)  x86_64
# 1548  #1 SMP Debian 4.19.171-2 (2021-01-30)  x86_64
#
#                                             source_file  \
# 0     /home/ivan/temp/temp-benchmarking/e2e1210/2021...
# 1     /home/ivan/temp/temp-benchmarking/e2e1210/2021...
# 2     /home/ivan/temp/temp-benchmarking/e2e1210/2021...
# 3     /home/ivan/temp/temp-benchmarking/e2e1210/2021...
# 4     /home/ivan/temp/temp-benchmarking/e2e1210/2021...
# ...                                                 ...
# 1544  /home/ivan/temp/temp-benchmarking/e2e1210/2021...
# 1545  /home/ivan/temp/temp-benchmarking/e2e1210/2021...
# 1546  /home/ivan/temp/temp-benchmarking/e2e1210/2021...
# 1547  /home/ivan/temp/temp-benchmarking/e2e1210/2021...
# 1548  /home/ivan/temp/temp-benchmarking/e2e1210/2021...
#
#                                                   run
# 0     20211012f183310_benchmark_e2e_s3_512_16_32_sync
# 1     20211012f183310_benchmark_e2e_s3_512_16_32_sync
# 2     20211012f183310_benchmark_e2e_s3_512_16_32_sync
# 3     20211012f183310_benchmark_e2e_s3_512_16_32_sync
# 4     20211012f183310_benchmark_e2e_s3_512_16_32_sync
# ...                                               ...
# 1544  20211012f174126_benchmark_e2e_s3_128_16_32_sync
# 1545  20211012f174126_benchmark_e2e_s3_128_16_32_sync
# 1546  20211012f174126_benchmark_e2e_s3_128_16_32_sync
# 1547  20211012f174126_benchmark_e2e_s3_128_16_32_sync
# 1548  20211012f174126_benchmark_e2e_s3_128_16_32_sync
#
# [1547466 rows x 96 columns]

# %%
df_dataloader_vanilla["run"]
# Out:
# 0       20211012f135612_benchmark_e2e_s3_128_16_32_sync
# 1       20211012f135612_benchmark_e2e_s3_128_16_32_sync
# 2       20211012f135612_benchmark_e2e_s3_128_16_32_sync
# 3       20211012f135612_benchmark_e2e_s3_128_16_32_sync
# 4       20211012f135612_benchmark_e2e_s3_128_16_32_sync
#                              ...
# 1535    20211012f151222_benchmark_e2e_s3_512_16_32_sync
# 1536    20211012f151222_benchmark_e2e_s3_512_16_32_sync
# 1537    20211012f151222_benchmark_e2e_s3_512_16_32_sync
# 1538    20211012f151222_benchmark_e2e_s3_512_16_32_sync
# 1539    20211012f151222_benchmark_e2e_s3_512_16_32_sync
# Name: run, Length: 1547466, dtype: object

# %%
df_s3_gpu_util = extract_gpu_utilization(output_base_folder, folder_filter=s3_folder_filter,device_id=2)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 18/18 [00:01<00:00, 14.43it/s]

# %%
df_s3_gpu_util
# Out:
#                                                 run  \
# 0   20211012f135612_benchmark_e2e_s3_128_16_32_sync
# 1   20211012f154048_benchmark_e2e_s3_512_16_32_sync
# 2   20211012f164815_benchmark_e2e_s3_256_16_32_sync
# 3   20211012f183310_benchmark_e2e_s3_512_16_32_sync
# 4   20211012f163540_benchmark_e2e_s3_256_16_32_sync
# 5   20211012f182037_benchmark_e2e_s3_512_16_32_sync
# 6   20211012f162211_benchmark_e2e_s3_128_16_32_sync
# 7   20211012f132417_benchmark_e2e_s3_128_16_32_sync
# 8   20211012f180743_benchmark_e2e_s3_256_16_32_sync
# 9   20211012f170122_benchmark_e2e_s3_512_16_32_sync
# 10  20211012f160911_benchmark_e2e_s3_128_16_32_sync
# 11  20211012f144730_benchmark_e2e_s3_256_16_32_sync
# 12  20211012f142224_benchmark_e2e_s3_256_16_32_sync
# 13  20211012f175454_benchmark_e2e_s3_256_16_32_sync
# 14  20211012f151222_benchmark_e2e_s3_512_16_32_sync
# 15  20211012f172814_benchmark_e2e_s3_128_16_32_sync
# 16  20211012f171449_benchmark_e2e_s3_512_16_32_sync
# 17  20211012f174126_benchmark_e2e_s3_128_16_32_sync
#
#                                                   gpu  gpu_mean  gpu_median  \
# 0   [4.0, 10.0, 0.0, 0.0, 34.0, 64.0, 73.0, 0.0, 1...   54.1350        61.5
# 1   [18.0, 100.0, 30.0, 91.0, 15.0, 100.0, 13.0, 6...   50.7600        54.5
# 2   [41.0, 55.0, 39.0, 69.0, 24.0, 33.0, 12.0, 100...   50.8250        53.5
# 3   [15.0, 36.0, 29.0, 27.0, 13.0, 52.0, 9.0, 93.0...   46.3700        33.5
# 4   [2.0, 13.0, 36.0, 42.0, 7.0, 86.0, 64.0, 67.0,...   52.8000        55.0
# 5   [4.0, 64.0, 15.0, 100.0, 4.0, 64.0, 10.0, 91.0...   45.3600        34.5
# 6   [3.0, 88.0, 4.0, 74.0, 34.0, 50.0, 7.0, 80.0, ...   56.8175        61.5
# 7   [76.0, 66.0, 74.0, 44.0, 57.0, 49.0, 91.0, 71....   57.1850        62.0
# 8   [8.0, 67.0, 50.0, 57.0, 0.0, 80.0, 7.0, 3.0, 8...   51.9000        56.0
# 9   [3.0, 61.0, 12.0, 0.0, 10.0, 75.0, 15.0, 8.0, ...   43.5300        35.0
# 10  [0.0, 0.0, 10.0, 12.0, 4.0, 70.0, 58.0, 58.0, ...   54.7125        60.0
# 11  [45.0, 40.0, 95.0, 69.0, 16.0, 100.0, 86.0, 61...   54.3500        54.5
# 12  [42.0, 36.0, 51.0, 100.0, 59.0, 67.0, 40.0, 10...   55.0900        58.0
# 13  [0.0, 2.0, 15.0, 33.0, 8.0, 10.0, 64.0, 62.0, ...   50.0800        52.5
# 14  [15.0, 99.0, 37.0, 100.0, 15.0, 49.0, 41.0, 40...   37.8600        32.0
# 15  [4.0, 59.0, 0.0, 8.0, 44.0, 79.0, 63.0, 62.0, ...   34.2450        31.0
# 16  [8.0, 91.0, 15.0, 4.0, 9.0, 92.0, 60.0, 100.0,...   49.0800        45.0
# 17  [4.0, 26.0, 88.0, 87.0, 64.0, 88.0, 69.0, 80.0...   54.1725        59.0
#
#           std
# 0   28.772587
# 1   34.643071
# 2   34.132600
# 3   35.186547
# 4   33.843611
# 5   34.164461
# 6   26.030351
# 7   26.601988
# 8   34.623258
# 9   35.409167
# 10  26.340840
# 11  32.927306
# 12  31.113532
# 13  30.750993
# 14  28.688681
# 15  26.752476
# 16  35.725531
# 17  26.692841

# %%
group_by_dataloader = ["dataset", "batch_size", "fetch_impl", "prefetch_factor"]

# %%
# tmp
for i in range(10):
    tmp = df_dataloader_async[df_dataloader_async["run"]=="20211012f183310_benchmark_e2e_s3_512_16_32_sync"]
    pd.set_option('display.float_format', lambda x: '%.8f' % x)
    iloc = i
    t = tmp[(tmp["trace_level"]==4)]
    st=t["time_start"].iloc[iloc] #1634056846.19644
    et=t["time_end"].iloc[iloc]#1634056957.99265
    pid=t["pid"].iloc[iloc] #31141

    print("Elapsed: ", t["elapsed"].iloc[iloc])

    del t
    len(tmp)
    elapsed_fetch = tmp[(tmp["trace_level"]==5) & 
                        (tmp["time_start"]>st) & 
                        (tmp["time_end"]<et) &
                        (tmp["pid"]==pid)]["elapsed"]
    del tmp
    elapsed_fetch=np.array(elapsed_fetch)
    len(elapsed_fetch)
    print("Sum: ", elapsed_fetch.sum()/32) # is it duplicated?!
# Out:
# Elapsed:  111.79620623588562
# Sum:  212.9207562629599
# Elapsed:  8.166375920176506
# Sum:  9.030058499891311
# Elapsed:  6.944346487522125
# Sum:  8.110553801292554
# Elapsed:  111.75160793960094
# Sum:  213.57050913549028
# Elapsed:  7.649163406342268
# Sum:  8.678384204627946
# Elapsed:  7.174958243966103
# Sum:  8.862631790339947
# Elapsed:  105.94267120957375
# Sum:  200.60389450308867
# Elapsed:  7.548595130443573
# Sum:  9.044641998130828
# Elapsed:  6.708854854106903
# Sum:  8.655934465117753
# Elapsed:  108.68699282035232
# Sum:  160.15219743456692

# %%
tmp = df_dataloader_async[df_dataloader_async["run"]=="20211012f183310_benchmark_e2e_s3_512_16_32_sync"].drop_duplicates()
tmp2 = df_dataloader_vanilla[df_dataloader_vanilla["run"]=="20211012f151222_benchmark_e2e_s3_512_16_32_sync"].drop_duplicates()

# %%
# 3 = _worker_loop
# 4 = fetch
# 5 = __getitem__
# 6 = training_step

for tl in [3, 4, 5, 6, 8]:
    f1 = tmp[tmp["trace_level"]==tl]
    f2 = tmp2[tmp2["trace_level"]==tl]
#     print(len(f))
    all_elapsed1 = np.array(f1["elapsed"])
    all_elapsed2 = np.array(f2["elapsed"])
    fig, ax = plt.subplots(figsize=(15, 10))
    ax.plot(all_elapsed1, color="red")    
    ax.plot(all_elapsed2, color="green")

# %%
f1 = tmp[tmp["trace_level"]==6]
f2 = tmp2[tmp2["trace_level"]==6]
#     print(len(f))
all_elapsed1 = np.array(f1["elapsed"])[10:]
all_elapsed2 = np.array(f2["elapsed"])[10:]
fig, ax = plt.subplots(figsize=(15, 10))
ax.plot(all_elapsed1, color="red")    
ax.plot(all_elapsed2, color="green")

# %%
print(np.unique(tmp["trace_level"].to_numpy()))
# Out:
# [3 4 5 6 8]

# %%
# 3 = _worker_loop
# 4 = fetch
# 5 = __getitem__
# 6 = training_step

def cnt(ds):
    f2 = ds[ds["trace_level"]==3]
    f2 = f2[10:]
    st=f2["time_start"].iloc[0] #1634056846.19644
    et=f2["time_end"].iloc[-1]#1634056957.99265
    f2 = ds[(ds["trace_level"]==5) & (ds["time_start"] >= st) & (ds["time_end"] <= et)]
    tp = len(f2) / (et-st)
    return len(f2), tp

# %%
f1, tp1 = cnt(tmp)
f2, tp2 = cnt(tmp2)

# %%
print(f"Throughput acync: {f1}, {tp1}")
print(f"Throughput vanilla: {f2}, {tp2}")
# Out:
# Throughput acync: 256000, 342.11284579963194
# Throughput vanilla: 102400, 151.95186936747123
